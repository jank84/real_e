# %%
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

# %%
import sklearn
#from StringIO import StringIO

# %%
#dataset = np.genfromtxt("real-estate.txt", delimiter="\t", usecols=[0,1,2,3,4,5,8,9],  names=True, dtype=(
#    int,int,int,int,int,int,int,int) )
#dataset[:5]

# %%
# read data
df = pd.read_csv("real-estate.txt", sep="\t", header=0)
df.head()
# Out:
#     Price  Living area  bedrooms  bathrooms  year  garage date collected  \
# 0  550000         2800         4        3.0  1940       2        1/21/09
# 1  619900         2770         4        3.0  1924       1        1/21/09
# 2  499862         2184         4        2.0  1926       2        1/21/09
# 3  629000         2105         4        2.0  1927       2        1/21/09
# 4  539900         2152         3        3.0  1927       2        1/21/09
#
#   location type  Urban  Suburb  Rural
# 0             u      1       0      0
# 1             u      1       0      0
# 2             u      1       0      0
# 3             u      1       0      0
# 4             u      1       0      0

# %%
# get lines with missing values -> useless
print(df.isnull().sum())
print(df.count())
# Out:
# Price             0
# Living area       0
# bedrooms          0
# bathrooms         1
# year              0
# garage            0
# date collected    0
# location type     0
# Urban             0
# Suburb            0
# Rural             0
# dtype: int64
# Price             894
# Living area       894
# bedrooms          894
# bathrooms         893
# year              894
# garage            894
# date collected    894
# location type     894
# Urban             894
# Suburb            894
# Rural             894
# dtype: int64

# %%
# in column bathrooms 1 value is missing
# df = df.dropna(axis='columns') # drop whol column ?
df = df.dropna() # or only 1 line
print(df.isnull().sum())
print(df.count())
# Out:
# Price             0
# Living area       0
# bedrooms          0
# bathrooms         0
# year              0
# garage            0
# date collected    0
# location type     0
# Urban             0
# Suburb            0
# Rural             0
# dtype: int64
# Price             893
# Living area       893
# bedrooms          893
# bathrooms         893
# year              893
# garage            893
# date collected    893
# location type     893
# Urban             893
# Suburb            893
# Rural             893
# dtype: int64

# %%
correlation_matrix = df.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# # conclusion
#
# ## convariance matrix result
#
# - price strongly depends on _living area_ and _bedrooms_ (`>.35`)
# - price develops divergent to _Rural_, which

# %%
df.head()
# Out:
#     Price  Living area  bedrooms  bathrooms  year  garage date collected  \
# 0  550000         2800         4        3.0  1940       2        1/21/09
# 1  619900         2770         4        3.0  1924       1        1/21/09
# 2  499862         2184         4        2.0  1926       2        1/21/09
# 3  629000         2105         4        2.0  1927       2        1/21/09
# 4  539900         2152         3        3.0  1927       2        1/21/09
#
#   location type  Urban  Suburb  Rural
# 0             u      1       0      0
# 1             u      1       0      0
# 2             u      1       0      0
# 3             u      1       0      0
# 4             u      1       0      0

# %%
df3 = pd.DataFrame({'X_Axis':[1,3,5,7,10,20],
                   'col_2':[.4,.5,.4,.5,.5,.4],
                   'col_3':[.7,.8,.9,.4,.2,.3],
                   'col_4':[.1,.3,.5,.7,.1,.0],
                   'col_5':[.5,.3,.6,.9,.2,.4]})
df3

df3_melt = df3.melt('X_Axis', var_name='cols',  value_name='vals')
g = sns.factorplot(x="X_Axis", y="vals", hue='cols', data=df3_melt)

# %%
sns.jointplot("year", "Price", data=df, kind='reg');

# %%
sns.relplot(x="year", y="signal", hue="event", kind="line", data=fmri);

# %%
#df.head()
#df["year"]
sns.jointplot("Price", "year", data=df, kind='reg');

# %%
sns.jointplot("Living area", "year", data=df, kind='reg');

# %%
#df.melt(id_vars=[('year','Price')], value_vars=[('bathrooms', 'garage')])
#print (df)
df_melt = df.melt('year', var_name='cols',  value_name='vals')
g = sns.factorplot(x="year", y="vals", hue='cols', data=df_melt[:20])

# %%
# Create some data
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y = np.cumsum(rng.randn(500, 6), 0)
# Plot the data with Matplotlib defaults
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');

# %%
import seaborn as sns
sns.set()
# same plotting code as above!
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left');
