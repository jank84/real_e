# %%
import numpy as np
import matplotlib.pyplot as plt 

import pandas as pd  
import seaborn as sns 

# %matplotlib inline

# %%
import sklearn

# %%
from sklearn.datasets import load_boston
boston_dataset = load_boston()

# %%
boston_dataset.data
# Out:
# array([[  6.32000000e-03,   1.80000000e+01,   2.31000000e+00, ...,
#           1.53000000e+01,   3.96900000e+02,   4.98000000e+00],
#        [  2.73100000e-02,   0.00000000e+00,   7.07000000e+00, ...,
#           1.78000000e+01,   3.96900000e+02,   9.14000000e+00],
#        [  2.72900000e-02,   0.00000000e+00,   7.07000000e+00, ...,
#           1.78000000e+01,   3.92830000e+02,   4.03000000e+00],
#        ...,
#        [  6.07600000e-02,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.96900000e+02,   5.64000000e+00],
#        [  1.09590000e-01,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.93450000e+02,   6.48000000e+00],
#        [  4.74100000e-02,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.96900000e+02,   7.88000000e+00]])

# %%
#sklearn.datasets.load_files("real-estate.txt")
dataset = np.loadtxt("real-estate.txt", delimiter="\t")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-e32807a0f699> in <module>()
#       1 #sklearn.datasets.load_files("real-estate.txt")
# ----> 2 dataset = np.loadtxt("real-estate.txt", delimiter="\t")
#
# C:\tools\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     983
#     984             # Convert each value according to its column and store
# --> 985             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     986             # Then pack it according to the dtype's nesting
#     987             items = pack_items(items, packing)
#
# C:\tools\Anaconda3\lib\site-packages\numpy\lib\npyio.py in <listcomp>(.0)
#     983
#     984             # Convert each value according to its column and store
# ...

# %%
dataset = np.genfromtxt("real-estate.txt", delimiter="\t", names=True, dtype=(int, int, int, int, int, int,
                                                                              string, string, int, int))
dataset
# Out:
# array([( 550000, 2800, 4,  3, 1940, 2, '', '', 1, 0),
#        ( 619900, 2770, 4,  3, 1924, 1, '', '', 1, 0),
#        ( 499862, 2184, 4,  2, 1926, 2, '', '', 1, 0),
#        ( 629000, 2105, 4,  2, 1927, 2, '', '', 1, 0),
#        ( 539900, 2152, 3,  3, 1927, 2, '', '', 1, 0),
#        ( 759000, 2240, 3,  3, 1909, 2, '', '', 1, 0),
#        ( 300000, 1617, 4,  3, 1973, 2, '', '', 0, 1),
#        ( 300000, 2600, 4,  2, 1941, 0, '', '', 0, 1),
#        ( 700000, 2550, 4,  3, 1954, 2, '', '', 0, 1),
#        ( 699999, 3500, 5,  4, 1928, 3, '', '', 0, 1),
#        ( 699999, 2760, 5,  3, 1942, 3, '', '', 0, 1),
#        ( 499999, 3576, 4,  3, 1985, 2, '', '', 0, 1),
#        ( 419900, 4155, 4,  3, 1987, 2, '', '', 0, 0),
#        ( 699000, 3700, 5,  4, 1986, 2, '', '', 0, 0),
#        ( 595000, 3752, 5,  3, 1996, 2, '', '', 0, 1),
#        ( 499900, 2754, 4,  2, 2002, 2, '', '', 0, 1),
#        ( 468850, 2800, 5,  3, 1996, 2, '', '', 0, 1),
# ...
